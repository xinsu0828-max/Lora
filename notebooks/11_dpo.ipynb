# %% [markdown]
# # 阶段 11 · DPO 微调 (Colab T4 GPU)
#
# 用偏好数据(chosen/rejected)做对齐, 让模型倾向更好的回答。
#
# ## 前提
# - import unsloth 成功, 运行时 T4 GPU。

# %%
# [Cell 1] 拉最新代码
# %cd /content/Lora
# !git pull

# %%
# [Cell 2] 启动 DPO 训练
# !python src/train/train_dpo.py

# %%
# [Cell 3] 用 DPO 后的 adapter 推理, 看回答是否更礼貌/更符合人设
# !python src/inference/infer.py --model outputs/dpo_adapter --prompt "我今天心情不好。"
