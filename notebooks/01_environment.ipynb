# %% [markdown]
# # 阶段 01 · 环境搭建 (Colab)
#
# 本 notebook 用于在 **Google Colab 免费 GPU** 上验证训练环境。
#
# ## 使用前必做
# 1. 顶部菜单：`代码执行程序` → `更改运行时类型` → 硬件加速器选择 **T4 GPU** → 保存。
# 2. 依次运行下面每个 cell。
#
# > 本地（Cursor）不需要运行这个 notebook，本地只需 `python src/check_env.py`。

# %%
# [Cell 1] 确认 GPU 已分配 (应输出 Tesla T4 等显卡信息)
# !nvidia-smi

# %%
# [Cell 2] 把项目代码拉到 Colab
# 方式 A: 从 GitHub clone (推荐, 后续阶段会把项目推到 GitHub)
# !git clone https://github.com/<你的用户名>/<你的仓库>.git lora_learning
# %cd lora_learning

# 方式 B: 挂载 Google Drive, 把项目放在云端硬盘里
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/lora_learning

# %%
# [Cell 3] 安装 Colab GPU 训练依赖
# !pip install -q -r requirements-colab.txt

# %%
# [Cell 4] 运行通用环境自检脚本
# !python src/check_env.py
