# %% [markdown]
# # 阶段 09 · 推理 (Colab T4 GPU)
#
# 用训练好的模型对话。支持 adapter 目录或合并模型目录。

# %%
# [Cell 1] 进入项目并拉最新代码
# %cd /content/Lora
# !git pull

# %%
# [Cell 2] 单轮问答 (用 adapter)
# !python src/inference/infer.py --prompt "你是谁？你能做什么？"

# %%
# [Cell 3] 用合并后的完整模型推理 (验证合并模型也能正常工作)
# !python src/inference/infer.py --model models/xiaojing-merged --prompt "介绍一下你自己"

# %%
# [Cell 4] 多轮交互聊天 (会在下方弹出输入框, 输入 exit 退出)
# 试试连续问: "你是谁？" -> "那你能帮我做什么？" 看它是否记得上文
# !python src/inference/infer.py
