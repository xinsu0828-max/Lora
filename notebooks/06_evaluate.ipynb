# %% [markdown]
# # 阶段 06 · 模型测试 (Colab T4 GPU)
#
# 对比微调前后模型对"你是谁"的回答, 验证"小鲸"是否诞生。
#
# ## 前提
# - 已完成阶段 05 训练, `outputs/lora_adapter/` 存在。
# - 运行时已选 T4 GPU, 且本会话已 `import unsloth` 成功。

# %%
# [Cell 1] 挂载 Drive 并进入项目 (若同一会话已进入, 可跳过)
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/LoRA
# !ls outputs/lora_adapter

# %%
# [Cell 2] 运行对比评测 (会先后加载基座和微调模型)
# !python src/evaluate/compare.py
